# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset('iris')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# We have 5 variables: sepal_length, sepal_width, petal_length, petal_width and species.
# 4 variables are in type float and one is an object.
# 150 observasions.

# %%
min_petal_width = iris['petal_width'].min()
max_petal_width = iris['petal_width'].max()

print (min_petal_width, max_petal_width)
# Out:
# 0.1 2.5

# %%
iris['petal_length'].median()
# Out:
# 4.35

# %%
iris['sepal_length'].mean()
# Out:
# 5.843333333333334

# %%
iris.groupby('species')['sepal_length'].mean()
# Out:
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal_length, dtype: float64

# %%
sns.barplot(x='species', y='sepal_length', data=iris, estimator=np.mean)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
iris.groupby('species')['sepal_width'].median()
# Out:
# species
# setosa        3.4
# versicolor    2.8
# virginica     3.0
# Name: sepal_width, dtype: float64

# %%
sns.barplot(x='species', y='sepal_width', data=iris, estimator=np.median, palette="Set2")
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
iris['species'].value_counts() #Observations per species
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
sns.barplot(x='species', y='sepal_length', data=iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris, hue='species' )
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lmplot(x='petal_length', y='petal_width', data=iris, hue='species')
# Out:
# C:\Users\Marko\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(x='petal_width',y='petal_length',hue="species",palette="Set1",height=6,aspect=2,data=iris, markers=["o","s", "D"])
# Out:
# C:\Users\Marko\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
